-- %%
-- 1. Creamos el Catálogo (Contenedor principal)
CREATE CATALOG IF NOT EXISTS test;
USE CATALOG test;

-- 2. Esquema para el proyecto (Capa lógica)
CREATE SCHEMA IF NOT EXISTS socioeconomics;
USE SCHEMA socioeconomics;

-- 3. Volume para el Landing Zone (Donde caerán los archivos de la API)
CREATE VOLUME IF NOT EXISTS landing_zone;
