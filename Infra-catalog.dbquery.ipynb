-- %%
-- 1. Zona de archivos (Volumes)
CREATE SCHEMA IF NOT EXISTS socioeconomics.landing;
CREATE VOLUME IF NOT EXISTS socioeconomics.landing.world_bank;
CREATE VOLUME IF NOT EXISTS socioeconomics.landing.checkpoints;

-- 2. Zona de tablas (Medallion)
CREATE SCHEMA IF NOT EXISTS socioeconomics.bronze;
CREATE SCHEMA IF NOT EXISTS socioeconomics.silver;
CREATE SCHEMA IF NOT EXISTS socioeconomics.gold;
